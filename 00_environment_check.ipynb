# %% [markdown]
# This notebook takes care of installation process for Flinc, so you can directly access the kernels and run a sample notebook.

# %%
import sys

### Clone Flinc
# !git clone https://github.com/radiant-systems-lab/Flinc.git

# %cd Flinc

### Clone Sciunit
# !git clone https://github.com/radiant-systems-lab/sciunit.git

# %cd sciunit

### Ensure branch visibility
# !git fetch
# !git checkout fix-sciunit-copy

### Install build dependency
# !{sys.executable} -m pip install cmake==3.22.1

### Install Sciunit
# !{sys.executable} -m pip install .

### switch to Flinc
# %cd ..

### Switch to nasa-demo (IN SCIUNIT)
# !git checkout nasa-demo

### Run installer (non-interactive safe)
# !bash ./install.sh /opt/conda/share/jupyter/kernels/python3
